# %% [markdown]
# # 02 — Control Flow and Functions
#
# ## Learning goals
# - Use if/elif/else for decisions
# - Use loops for repetition
# - Write reusable functions

# %%
score = 83

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
else:
    grade = "D"

print("Grade:", grade)
# Out:
# Grade: B

# %%
# Loops
nums = [2, 4, 6, 8]
total = 0
for n in nums:
    total += n

print("Total:", total)
# Out:
# Total: 20

# %%
# Functions
def celsius_to_fahrenheit(c):
    return (c * 9/5) + 32

print(celsius_to_fahrenheit(25))
# Out:
# 77.0

# %%
# Practice task:
# Write a function called is_even(n) that returns True/False.

# %%
def is_even(n):
    return n % 2 == 0  # Returns True if n is divisible by 2, else False


print(is_even(4))  # True
print(is_even(7))  # False
# Out:
# True
# False
